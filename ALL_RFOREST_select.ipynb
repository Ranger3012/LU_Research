# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)

# %cd 'drive/MyDrive/LU_Research'
# !ls
# Out:
# Mounted at /content/drive
# /content/drive/MyDrive/LU_Research
#  ALL_Bagging_SELECT.ipynb       ANN_V1.ipynb
#  ALL_Bagging_V1.ipynb	        col_names.pkl
#  ALL_Bagging_V2.ipynb	       'dense_NN (1).ipynb'
#  ALL_dense_final.ipynb	        features.pkl
#  ALL_dense_final_v2.ipynb       get_data_v1.ipynb
#  ALL_DENSE_V1.ipynb	        get_data_v2.ipynb
#  all_GNAIVE_BAYES_Graph.ipynb   Inst_ALL_RFOREST_V1.ipynb
#  all_GNAIVE_BAYES_V1.ipynb      KNN_V1_10_90.ipynb
#  all_GNAIVE_BAYES_V2.ipynb      labels.pkl
#  ALL_KNN_Select_K.ipynb         LR_V1.ipynb
#  ALL_KNN_V1.ipynb	        MLP_v1_10_90.ipynb
#  ALL_KNN_V2.ipynb	        NB_V1.ipynb
#  ALL_KNN_V3.ipynb	       'PANCANCER_ANOVA_Sun Nov 20 23_09_56 2022 (1).csv'
#  ALL_LSTM_v1.ipynb	        PPI_v1.ipynb
#  ALL_LSTM_v2.ipynb	        PPI_v2.ipynb
#  ALL_MLP_Select.ipynb	        PPI_V3.ipynb
#  ALL_MLP_v1.ipynb	        RFE_v1.ipynb
#  ALL_MLP_v2.ipynb	        RNN_V1.ipynb
#  ALL_RFOREST_select.ipynb       RNN_v2.ipynb
#  ALL_RFOREST_V1.ipynb	        RNN_v3.ipynb
#  ALL_RFOREST_V2.ipynb	        SelectK_RNN_v2.ipynb
#  All_RNN_v1.ipynb	        xgboost_10_90.ipynb
#  All_RNN_v2.ipynb	        xgboost_10_90_v1.ipynb
#  ALL_SVM_V1.ipynb	        xgboost_20_80.ipynb
#  ALL_SVM_V2_70_60.ipynb         xgboost_30_70.ipynb
#  ALL_SVM_V2_90_80.ipynb         xgboost_40_60.ipynb
#  ALL_Transformer_60_40.ipynb    xgboost_50_50.ipynb
#  ALL_Transformer_v1.ipynb       xgboost_60_40.ipynb
#  ALL_XGBOOST_select_N.ipynb     xgboost_70_30.ipynb
#  ALL_XGBOOST_V1.ipynb	        xgboost_80_20.ipynb
#  ALL_XGBOOST_V2.ipynb	        xgboost_90_10.ipynb
#  ALL_XGBOOST_V3.ipynb

# %%
import pickle
import numpy as np
import xgboost as xgb
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split, cross_val_score, KFold
from sklearn.metrics import classification_report, confusion_matrix, recall_score, precision_score

# Load feature and label data from pickle files
with open('features.pkl', 'rb') as handle:
    X = pickle.load(handle)

with open('labels.pkl', 'rb') as handle:
    y = pickle.load(handle)

# Convert data to numpy arrays
X = np.array(X)
y = np.array(y)

# %%
# Encode labels
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
y_enc = le.fit_transform(y)

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import accuracy_score

# Define classifier

clf = RandomForestClassifier()

# Define grid search parameters
param_grid = {
    'n_estimators': [5,8,10]
}


# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y_enc, test_size=0.2, random_state=42)

# Perform grid search
grid_search = GridSearchCV(clf, param_grid, cv=5, scoring='accuracy')
grid_search.fit(X, y_enc)

# Print best parameters and score
print("Best parameters: ", grid_search.best_params_)
print("Best score: {:.2f}".format(grid_search.best_score_))

# Train and test the classifier with the best parameters
best_clf = grid_search.best_estimator_
best_clf.fit(X_train, y_train)
y_pred = best_clf.predict(X_test)
acc = accuracy_score(y_test, y_pred)
print("Test accuracy: {:.2f}".format(acc))
# Out:
# Best parameters:  {'n_estimators': 10}
# Best score: 0.97
# Test accuracy: 1.00
